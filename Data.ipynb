# %% [markdown]
# https://s3.amazonaws.com/tripdata/index.html

# %%
# Step 1: Import pandas
import pandas as pd

# Step 2: Read the CSV file
file_path = '/Users/bricenfisher/Downloads/2023-citibike-tripdata/12_December/202312-citibike-tripdata_3.csv'  # Replace with the path to your CSV file
df = pd.read_csv(file_path)
# Out:
# /var/folders/wm/w3d80c152lq65mt41y20p1200000gn/T/ipykernel_88757/1236260677.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])

df['Duration'] = df['ended_at'] - df['started_at']

# %%
print(df)
# Out:
#                  ride_id rideable_type          started_at  \
# 0       FB81AC70BBE6A468  classic_bike 2023-12-07 11:26:27
# 1       75B358491F447D9A  classic_bike 2023-12-05 05:52:13
# 2       DBB3F24147152EDF  classic_bike 2023-12-05 12:07:08
# 3       C3F0015643BA2AE7  classic_bike 2023-12-16 11:38:42
# 4       5949386BEEA73393  classic_bike 2023-12-03 19:05:31
# ...                  ...           ...                 ...
# 273660  796BC679FFED8FB8  classic_bike 2023-12-14 10:01:36
# 273661  A8FFE1251749A510  classic_bike 2023-12-14 10:13:42
# 273662  AC14339B505A0000  classic_bike 2023-12-14 10:09:56
# 273663  FC3702FD4319EC93  classic_bike 2023-12-14 10:03:47
# 273664  930E4226552E06D8  classic_bike 2023-12-17 13:15:50
#
#                   ended_at      start_station_name start_station_id  \
# 0      2023-12-07 11:29:54         6 Ave & W 34 St          6364.10
# 1      2023-12-05 05:54:50            4 Ave & 3 St          4028.04
# 2      2023-12-05 12:24:18   Park Circle & East Dr          3344.02
# 3      2023-12-16 12:03:35  Riverside Dr & W 91 St          7524.16
# 4      2023-12-03 19:19:55   Park Circle & East Dr          3344.02
# ...                    ...                     ...              ...
# 273660 2023-12-14 10:02:31     St Marks Pl & 1 Ave          5626.13
# 273661 2023-12-14 10:14:27     St Marks Pl & 1 Ave          5626.13
# 273662 2023-12-14 10:10:44     St Marks Pl & 1 Ave          5626.13
# 273663 2023-12-14 10:04:36     St Marks Pl & 1 Ave          5626.13
# 273664 2023-12-17 13:16:46     St Marks Pl & 1 Ave          5626.13
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0              Broadway & W 38 St        6560.15  40.749656 -73.988212
# 1             Douglass St & 4 Ave        4175.14  40.673746 -73.985649
# 2       Sterling St & Bedford Ave        3665.06  40.651566 -73.972212
# 3         W 16 St & The High Line        6233.05  40.793421 -73.977041
# 4             Douglass St & 4 Ave        4175.14  40.651514 -73.972165
# ...                           ...            ...        ...        ...
# 273660        St Marks Pl & 2 Ave         5669.1  40.727791 -73.985649
# 273661        St Marks Pl & 2 Ave         5669.1  40.727791 -73.985649
# 273662        St Marks Pl & 2 Ave         5669.1  40.727791 -73.985649
# 273663        St Marks Pl & 2 Ave         5669.1  40.727791 -73.985649
# 273664        St Marks Pl & 2 Ave         5669.1  40.727791 -73.985649
#
#           end_lat    end_lng member_casual        Duration
# 0       40.752973 -73.987349        member 0 days 00:03:27
# 1       40.679279 -73.981540        member 0 days 00:02:37
# 2       40.662706 -73.956912        casual 0 days 00:17:10
# 3       40.743349 -74.006818        casual 0 days 00:24:53
# 4       40.679279 -73.981540        casual 0 days 00:14:24
# ...           ...        ...           ...             ...
# 273660  40.728419 -73.987140        member 0 days 00:00:55
# 273661  40.728419 -73.987140        member 0 days 00:00:45
# 273662  40.728419 -73.987140        member 0 days 00:00:48
# 273663  40.728419 -73.987140        member 0 days 00:00:49
# 273664  40.728419 -73.987140        member 0 days 00:00:56
#
# [273665 rows x 14 columns]

# %%
import matplotlib.pyplot as plt

# Plotting the points
plt.figure(figsize=(10, 6))
plt.scatter(df['end_lng'], df['end_lat'], c='blue', marker='o')

# Adding titles and labels
plt.title('Latitude and Longitude Points')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Show grid
plt.grid(True)

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact
 
 
def interactive_plot(amplitude, frequency):
    x = np.linspace(0, 2 * np.pi, 1000)
    y = amplitude * np.sin(frequency * x)
    plt.figure(figsize=(8, 4))
    plt.plot(x, y)
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('Interactive Sine Wave')
    plt.grid(True)
    plt.show()
 
 
interact(interactive_plot, amplitude=(1, 5, 0.1), frequency=(1, 10, 0.1))
# Out:
# interactive(children=(FloatSlider(value=3.0, description='amplitude', max=5.0, min=1.0), FloatSlider(value=5.0…
# <function __main__.interactive_plot(amplitude, frequency)>

# %%
import leafmap as leafmap
print(leafmap.basemaps.keys())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 import leafmap as leafmap
#       2 print(leafmap.basemaps.keys())
#
# ModuleNotFoundError: No module named 'leafmap'

# %%
leafmap.split_map(left_layer="ROADMAP", right_layer="HYBRID")
leafmap.split_map(
    left_layer="Esri.WorldTopoMap", right_layer="OpenTopoMap", zoom_control=False
)

leafmap.split_map(
    left_layer="NLCD 2001 CONUS Land Cover",
    right_layer="NLCD 2016 CONUS Land Cover",
    left_label="2001",
    right_label="2016",
    label_position="bottom",
    center=[36.1, -114.9],
    zoom=10,
)
